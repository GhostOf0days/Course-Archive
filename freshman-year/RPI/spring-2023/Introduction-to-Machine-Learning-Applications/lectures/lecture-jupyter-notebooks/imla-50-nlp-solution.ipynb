# %% [markdown]
# Using the text in one of the project CSV files:
#
#
# * Find the top 10 uni-, bi-, and tri-grams
# * Convert the text to BERT embeddings
# * Cluster the posts using these embeddings
# * Extract topics using these embeddings

# %%
# Install additional libraries

# !pip install bertopic
# !pip install gensim
# !pip install sentence-transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: bertopic in /usr/local/lib/python3.9/dist-packages (0.14.1)
# Requirement already satisfied: tqdm>=4.41.1 in /usr/local/lib/python3.9/dist-packages (from bertopic) (4.65.0)
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.9/dist-packages (from bertopic) (1.4.4)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.9/dist-packages (from bertopic) (1.22.4)
# Requirement already satisfied: sentence-transformers>=0.4.1 in /usr/local/lib/python3.9/dist-packages (from bertopic) (2.2.2)
# Requirement already satisfied: umap-learn>=0.5.0 in /usr/local/lib/python3.9/dist-packages (from bertopic) (0.5.3)
# Requirement already satisfied: plotly>=4.7.0 in /usr/local/lib/python3.9/dist-packages (from bertopic) (5.13.1)
# Requirement already satisfied: scikit-learn>=0.22.2.post1 in /usr/local/lib/python3.9/dist-packages (from bertopic) (1.2.2)
# Requirement already satisfied: hdbscan>=0.8.29 in /usr/local/lib/python3.9/dist-packages (from bertopic) (0.8.29)
# Requirement already satisfied: cython>=0.27 in /usr/local/lib/python3.9/dist-packages (from hdbscan>=0.8.29->bertopic) (0.29.33)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.9/dist-packages (from hdbscan>=0.8.29->bertopic) (1.10.1)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.9/dist-packages (from hdbscan>=0.8.29->bertopic) (1.1.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.1.5->bertopic) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.1.5->bertopic) (2.8.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from plotly>=4.7.0->bertopic) (8.2.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=0.22.2.post1->bertopic) (3.1.0)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /usr/local/lib/python3.9/dist-packages (from sentence-transformers>=0.4.1->bertopic) (4.27.2)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.9/dist-packages (from sentence-transformers>=0.4.1->bertopic) (0.14.1+cu116)
# Requirement already satisfied: nltk in /usr/local/lib/python3.9/dist-packages (from sentence-transformers>=0.4.1->bertopic) (3.8.1)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.9/dist-packages (from sentence-transformers>=0.4.1->bertopic) (0.1.97)
# Requirement already satisfied: huggingface-hub>=0.4.0 in /usr/local/lib/python3.9/dist-packages (from sentence-transformers>=0.4.1->bertopic) (0.13.3)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from sentence-transformers>=0.4.1->bertopic) (1.13.1+cu116)
# Requirement already satisfied: numba>=0.49 in /usr/local/lib/python3.9/dist-packages (from umap-learn>=0.5.0->bertopic) (0.56.4)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.9/dist-packages (from umap-learn>=0.5.0->bertopic) (0.5.8)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2.27.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (4.5.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (3.10.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (23.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.9/dist-packages (from numba>=0.49->umap-learn>=0.5.0->bertopic) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from numba>=0.49->umap-learn>=0.5.0->bertopic) (67.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas>=1.1.5->bertopic) (1.16.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (2022.10.31)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.9/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (0.13.2)
# Requirement already satisfied: click in /usr/local/lib/python3.9/dist-packages (from nltk->sentence-transformers>=0.4.1->bertopic) (8.1.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.9/dist-packages (from torchvision->sentence-transformers>=0.4.1->bertopic) (8.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (1.26.15)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: gensim in /usr/local/lib/python3.9/dist-packages (4.3.1)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.9/dist-packages (from gensim) (1.22.4)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.9/dist-packages (from gensim) (6.3.0)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.9/dist-packages (from gensim) (1.10.1)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.9/dist-packages (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from sentence-transformers) (1.22.4)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /usr/local/lib/python3.9/dist-packages (from sentence-transformers) (4.27.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.9/dist-packages (from sentence-transformers) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from sentence-transformers) (1.10.1)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from sentence-transformers) (1.13.1+cu116)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.9/dist-packages (from sentence-transformers) (0.1.97)
# Requirement already satisfied: huggingface-hub>=0.4.0 in /usr/local/lib/python3.9/dist-packages (from sentence-transformers) (0.13.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from sentence-transformers) (4.65.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.9/dist-packages (from sentence-transformers) (3.8.1)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.9/dist-packages (from sentence-transformers) (0.14.1+cu116)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (3.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (4.5.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (23.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (2.27.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (2022.10.31)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.9/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (0.13.2)
# Requirement already satisfied: click in /usr/local/lib/python3.9/dist-packages (from nltk->sentence-transformers) (8.1.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.9/dist-packages (from nltk->sentence-transformers) (1.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn->sentence-transformers) (3.1.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.9/dist-packages (from torchvision->sentence-transformers) (8.4.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2.0.12)

# %%
# Read the CSV file

import pandas as pd
df = pd.read_csv("GetEmployedForum.csv")

# %%
# Look at the comments
df["CommentContent"]
# Out:
# 0        that s actually 20 jobs in a month lol i didn ...
# 1        yeahh the shining shimmering splendid that is ...
# 2              thank you my friend i really appreciate it
# 3        first of all congratulations we all know how h...
# 4        absolutely is a factor i had the same issue wh...
#                                ...
# 52692    i literally can t do anything and this is how ...
# 52693    i d like to counter this two years out of coll...
# 52694             what do you do if you don t know people
# 52695    i can attest to this i make a fuck ton of mone...
# 52696    thanks this is awesome anyone reading please t...
# Name: CommentContent, Length: 52697, dtype: object

# %%
# Tokenize
from gensim.parsing.preprocessing import preprocess_string, remove_stopwords, strip_punctuation, strip_numeric, strip_multiple_whitespaces, strip_short, strip_tags

tokens = df["CommentContent"].apply(preprocess_string, filters=(
  lambda x: x.encode('utf-8').strip(),
  lambda x: x.lower(),
  strip_multiple_whitespaces,
  strip_tags,
  strip_numeric,
  strip_punctuation,
  strip_short,
  remove_stopwords
))
tokens
# Out:
# 0        [actually, jobs, month, lol, know, people, app...
# 1        [yeahh, shining, shimmering, splendid, network...
# 2                              [thank, friend, appreciate]
# 3        [congratulations, know, hard, best, interview,...
# 4        [absolutely, factor, issue, going, college, co...
#                                ...
# 52692                                    [literally, jobs]
# 52693    [like, counter, years, college, graduated, got...
# 52694                                       [know, people]
# 52695               [attest, fuck, ton, money, networking]
# 52696    [thanks, awesome, reading, talk, want, moderator]
# Name: CommentContent, Length: 52697, dtype: object

# %%
# Compute top n-grams

from collections import Counter
from nltk.util import ngrams

for n in (1, 2, 3):
  ngram_counter = Counter()
  for sentence_tokens in tokens:
    for ngram in ngrams(sentence_tokens, n):
        ngram_counter[ngram] += 1
  print(f"Most common {n}-grams:")
  print(ngram_counter.most_common(10))
  print()
# Out:
# Most common 1-grams:
# [(('job',), 24275), (('like',), 14008), (('work',), 13840), (('know',), 9736), (('good',), 9693), (('people',), 9509), (('time',), 9462), (('resume',), 9192), (('want',), 8742), (('experience',), 7410)]
#
# Most common 2-grams:
# [(('good', 'luck'), 2139), (('cover', 'letter'), 1664), (('let', 'know'), 1266), (('https', 'www'), 1131), (('entry', 'level'), 1071), (('job', 'search'), 992), (('sounds', 'like'), 963), (('hiring', 'manager'), 809), (('resources', 'like'), 804), (('career', 'resources'), 802)]
#
# Most common 3-grams:
# [(('ref', 'careerbot', 'free'), 460), (('let', 'know', 'comments'), 400), (('share', 'let', 'know'), 399), (('know', 'comments', 'add'), 399), (('hey', 'free', 'resources'), 398), (('free', 'resources', 'hope'), 398), (('resources', 'hope', 'useful'), 398), (('way', 'careerbot', 'reddit'), 398), (('careerbot', 'reddit', 'bot'), 398), (('reddit', 'bot', 'points'), 398)]

# %%
# Compute the embeddings
from sentence_transformers import SentenceTransformer
sentence_transformer = SentenceTransformer('distilbert-base-nli-mean-tokens')
# Treat each comment as a "sentence" so we're comparing comment-to-comment
sentences = df['CommentContent'].iloc[:500]  # Only use first n comments to make this fast enough to demo
sentences = [' '.join(sentence_tokens) for sentence_tokens in sentences.apply(preprocess_string, filters=(
  lambda x: x.encode('utf-8').strip(),
  lambda x: x.lower(),
  strip_multiple_whitespaces,
  strip_tags,
  strip_numeric,
  strip_punctuation,
  strip_short,
  remove_stopwords
)).tolist()]
sentence_embeddings = sentence_transformer.encode(sentences)

# %%
# Cluster with k-means

from sklearn.cluster import KMeans
num_clusters = 5
kmeans = KMeans(n_clusters=num_clusters)
kmeans.fit(sentence_embeddings)

clustered_sentences = [[] for i in range(num_clusters)]
for sentence_id, cluster_id in enumerate(kmeans.labels_):
    clustered_sentences[cluster_id].append(sentences[sentence_id])

for i, cluster in enumerate(clustered_sentences):
    print("Cluster ", i + 1)
    print(cluster)
    print("")
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Cluster  1
# ['brain car culture fuckcars', 'difficult know people discussing problem https blogs stonesteps', 'think applying different companies single day developed tailored resume definitely mistaken realistic advice way', 'problem graduated got months placement ended month sure employment gap matter', 'case deleted entire conversation thread remote angellist', 'incredibly disappointing applied tonight approximately places interview wednesday pay benefits better experience working lab', 'looking people lie time respond leverage nego', 'true hope job listing removed day interview knowthat mean coincidence good vibes interview', 'think appreciate passing wouldn overthink decision probably unlikely wound way basis verbal bouquet flowers face', 'times asked previous designation title different looking similar job duties dropped thought thing modify title requirement changing description work releving letter scares dropped lying title complex dillema', 'growing industry good career discouraged country bad situation', 'let manager know changed mind better let know business contact run away responsibility exiting interview process burn bridge need', 'applied ish positions year getting ghosted hurts actually start new career valentine day stick took year', 'honestly forget place interviewed gotten stage hopes anymore', 'want known money topic working constant disrespect interview kill allow people think ignore stupid habit picked time eliminated early', 'know companies aren intentionally ghosting probably overwhelmed traditional hiring process right broken head new avenues job searching want work company ghosts candidates', 'social media target audience wary algorithm end entrenching biases exist labour market white middle class people know standardised personality measurements imagine cultural bias needs considered interpreting', 'job care worth time job care usually limit follow ups hear sucks childish shit ghost people generally especially professional environment best luck friend', 'applying jobs apply higher chance employment thats went jobs stuck know sucks feel let pushing', 'sure weakness essential job going accounting fear public speaking list actively trying better area', 'good sign short offering job pivot maybe people interviewing bad pick phone going know job maybe ask legal reasons decline details', 'agree way interested based solely fact going qualified considered sudden pivot raised eyebrows going hear soon phone asking come week', 'better weakness weakness instead disguising strength weakness mention weakness mention effort putting overcome working weakness couple examples weaknesses include public speaking confidence multitasking', 'looking tough tough work suggest oil fields cynical nature best stability based experience toyota plants woodstock cambridge ontario difficult work glad temporary toyota realizes bills pay gives option come factory closed lack parts broken equipment', 'yeah feel like caught sooner noticed messages spam inbox consecutive check spam folder need mistake', 'contacted customer service position said happened weirdest thing stands fact recruiter keeps emailing single day stopped responding believing scam workforce way happens good luck', 'thats real legal department larger company fairly toxic culture reasons switching jobs near future', 'exactly title guess feeling guilty giving week deciding far lot favour leaving', 'yeah feel like loser sure think point nerves stuck position forever', 'feeling unwelcome reasonable reason leave job', 'feeling need look shoulder seconds start acting weird try lot close', 'miserable detrimental health live life better happy', 'mentally struggling job better let sooner later months exactly months today funny want prove getting opportunity want leave shitty reason', 'burnout stress mentally struggling job better let sooner later trust job culture toxic crying work single day felt underperforming stupid capable job new job culture super supportive shining requires thinking  ...
#
# Cluster  2
# ['thank friend appreciate', 'thanks follow', 'thank', 'thankss', 'lol know definitively', 'thanks help god bless', 'good luck', 'nyc', 'asked based state ofc', 'age', 'send follow thanks advice', 'center', 'thank', 'probably', '', 'fiverr', 'dropshipper', 'btw answer weakness', 'great tip thanks lot', 'tell', 'words speak minute speaking slowly giving room pauses', 'thanks concerned minute', 'enjoying feel unwelcomed', 'came exact thing', 'question point', 'point question', 'longer place respect opinion experience', 'america', 'thank reply', 'god evil', 'sure messaging', 'sure willing send mind personal parts', 'hiring', 'skills', 'cool commenting visibility', 'man good luck', 'public heath georgia mix', 'ask raise join', 'closer job', 'curiosity uber', 'uber problem yeah', 'agreed figure thinks weird', 'think thinking surprise lol', 'yaser', 'thank insight', 'title matter matters accomplished past know attitude', 'change', 'remind days', 'updates', 'like run calc enter drag coefficient area', 'lol', '', 'ahh yes iterduscions', 'kind leaning thanks', 'send direct message offer', 'graduate', 'thanks', 'whoa awesome def', 'replied', '', 'bachelors degree', 'thanks glad people like', 'cool thanks man', 'hmmm girl allow iterduse', 'pay', 'positions applying', 'thank', 'maybe meant type hit instead', 'post', 'started', 'worked']
#
# Cluster  3
# ['actually jobs month lol know people applying hundreds okay apply multiple positions company hear good practice', 'considering commute time relevant accepting job offer consider finding parking commute', 'tailoring cover letter talking match specific requirements experience soft skills personal qualities relevant examples try use job spec checklist use similar buzzwords use team player interpersonal experience working industry internships previous job roles', 'applying jobs week applying shouldifeedher understand niche field said transferrable skills broaden search start applying jobs real', 'linkedin premium subscription like month love learning platform cancel anytime marketing certs linkedin profile instructors good watch single videos course bunch learned ton skills way recruiters reaching gone way started', 'usually recruiter sets interviews hiring manager email exchange surprised hiring manager contact case ask recruiter hiring manager contact fue recruiter best hired recruiter gets paid', 'companies applicant time applying interviewing untill written signed offer asked applying multiple positions tell position interesting want considered', 'medical hiring different beast entirely experienced medical hiring different beast entirely upfront experienced names listed job postings employee directories send resume experiences easy write saying want considered multiple roles multiple locations let know traction method', 'looking jobs filter job search colorado state law positions listed post salary range look job title want boom rate convert depending cost living area want work baseline', 'got hired ghosted said day shifts annnnd wtf', 'sounds better actually politely ask recruiter forward email hiring managers', 'glassdoor good work bitech industry suggestions know phd pay academia time essence entry level depending job title looking figures', 'send email employer advantage state asked certificate employment help', 'recruiter appreciate overstep try reach managers way offer recruiters hired main point contact hire', 'apply job linkedin copy profile submits shows current profile change current job marketing apply marketing job change communications communications job hiring manager marketing current linkedin profile says communications want best linkedin detailed job duties job description job skills section possible profile looking new opportunities', 'work large tech company interface bdrs regularly prepared personality type test pre interviews use similar offered predictive index google bdr personality test sales hiring test understand look like', 'asap recruiters job interface comp know timeline reach ask recruiter paid hired getting board', 'look numbers game send resumes ping contacts gets callbacks interviews lead good job', 'want personality digitized want digital behavior determine qualification job company requires users thoughtful considerate online behavior user know personality digitized know social media profiles professional line think good picture candidates ability fit culture social media users live life offline especially sought candidates bother upkeeping digital personality lot recruiters target candidates based meetup facebook linkedin groups join super hit miss targeting keywords hit miss idea applicable generation raised social media gets senior leadership roles industries pending generation stays social media entire life', 'tutor kids english sites think vipkids', 'pitch check reources online kelangan kabisado like pag naala recite spot like said minute flop interview review kabisado ulit post inputs yung akin nga sabaw haha', 'knew guy started heard curious george tell story work life curiosity theme question remember concert related search event management role', 'weakness specific weakness job personal review job description compare looking good answer want experience software haven similar reviewed couple articles youtube videos different learn looks little different way started bookmarked trainin ...
#
# Cluster  4
# ['congratulations know hard best interview thank sharing hope hear soon', 'friend bought kick scooter scenario', 'great intel thanks friend', 'buy motorcycle park want', 'thought opposite personally rigid working hopefully shows applications', 'details thinking apply program worth learn', 'check metaflokirush function giving guaranteed income maximum fun time metaflokirush showing crazy progress check believe metaflokirush metaflokirush metaflokirushshillsquad metaflokirushtothemonn', 'congrats job think practical app asked sit field wouldn practical background experience deciding factor', 'welcome hope helps job search', 'advantage moves super quick probably tried times right person phone', 'wake early morning ready work manager gets', 'walk work employee', 'happened got hired told called day shifts happened waiting', 'browse job title level qualifications opportunities salaries label', 'know messages come night time like onwards day waiting time phone interview', 'thank think sending email thing morning', 'actually gave hope experience bother apply major maybe confident resume looks good', 'picked field incision working day today', 'thank reply specific goal want leave field', 'follow days later interview worked shows employer wanting', 'check coolworks com', 'sadly method work company wanted work wish', 'build look forward reading inevitable law suits', 'fivver sell lot services fivver', 'comments productive like wouldn use like data weird company want exaggerated social media explanation actually mean productive way communicating', 'sorry circumstances specific goal post result type response information enable people responses respond', 'social media', 'maybe time dog walker possibly mod sub million subscribers spare time', 'good sign interested spend man hours speaking likely correct want meet possibly sense long term goals good luck', 'tell tell career progression applying jobs hoping future minute explain', 'want jot couple words intro words craft statement key words focus connecting getting lot content', 'things answer question usually summary career maybe things particularly interested things free time think opportunity connect interviewers settle interview', 'unfortunately degree useful specific industry thanks commenting', 'service offer digitally speak second language translate', 'maybe saying feel like company right fit reason', 'thing actually want work prove given opportunities', 'reasons enjoy feel welcome need justify reason leaving job anybody leave enjoy team makes feel welcomed', 'need reason leave job life best need permission approval', 'know got downvoted absolutely correct cbt therapist help mindfulness huge help different things', 'wish similar situation job worry', 'join military maybe', 'deleting thread piece information thanks community helpful lot good advice', 'putting post brave thing place buddy taking steps right direction', 'appreciate recommendation definitely look know need comfort zone hopefully help', 'similar situation thing helped book reinventing steve chandler self help books aren usually thing got hump getting job know probably wanted succinct maybe help', 'digital marketing non digital marketing work experience previous work experience', 'convenient work webcam niche service fanscity best option', 'appreciate useful information wish known websites noted', 'want help fine offered want excuses nonstop face reality time messages sent woe attitude assisting deem reality strategies helping amp good luck future', 'owning printer want provide picture holding piece prove real person owned printer need provide piece identification wat', 'nice worked lot data engineers messaged', 'working webcam niche profitable use service fanscity work', 'earn money datalmfao honest guess', 'assume come going mentor going forward assume willing talk willing help default surprised great conversations great people meet assumption', 'add rapid growth career path benefits', 'models try use service fanscity work' ...
#
# Cluster  5
# ['yeahh shining shimmering splendid networking mind job require phd honestly girl broke thanks explaining', 'absolutely factor issue going college coop placement school order parking spot minute walk minutes school started later minute walk', 'post pandemic shadow time job isn specific degree need resume job specific degree feel need justify spend time list job better look month gap non degree work create sort portfolio unpaid experience work test client accredited companies accepting employment gaps school post graduation jobs candidates assume time wisely bad look', 'going harder train phd know easier harder train work force fot longer way sure employers open skills resume need job worth start building desirable skills untill try use network built post graduate studies know place need skills time know anyways', 'bit confused update based job description mean highlighting things focus phd things like task time want good task highlight thanks appreciate imposter syndrome getting stronger rejection hopefully job soon', 'yeah consensus apply wanted start application warly assumed entire application process months lot savings able finish phd apply hard commit somebody uncertainties', 'demand issue comment point harder train people phd open work areas outside phd like example transferable technicques skills indicated open work things nah', 'sure free got check ippei blog lead ippei course got best coaches patient ones comes digital marketing lead generation rank rent champion allow explore good comfortable ask advice portfolio ippei dan molded successful people rank rent industry years great paying home based career lets boss choose work time basically dream job', 'getting job tough present time biotech pharma industries growing industries require phd holder like advice active applying job application companies send try connect directly mentioned application got rejected time need look skill set provided need update job description companies mentioned way chances high interview round job matches profile wish best hope job soon', 'reason struggling help recommend follow good post phd profiles linkedin talk better argue transition academia industry follow jon tham jennifer polk chris cornthwaite worth finding people discuss industry area', 'lot phd friends overqualified companies think harder train', 'try week good effort research company listing people companies aren looking hold long usually listings filled open companies aren looking hold position open graduating mid months away know won able stage finishing phd want hold position waiting months', 'phd literally expanding human knowledge having masters demand niche working field mesh future phd skills desirable worthwhile encounter rookie numbers recently changed jobs gotten quick turnaround applied jobs week reasonably consider linkedin sure quick apply button lets speed pre interview questions apply jobs minute tldr specialized apply increase odds getting human', 'worry friend idea outmoded assumes hiring managers looking physical stack resumes days ats collect applications parse certain key words compiled list sent department figure applicants meet base qualifications phone screen interview list sent hiring manager hiring manager look applicants ats directly person hiring positions won applied positions department odds looking applications names blur', 'like positions field salary governed preexisting contract pay agreement says high paying field worried', 'fair maybe exactly overstatement idea seen successful mirroring language possible job description says garden hose shouldn write water conveyor tube stranger know job needs able assess closely skills line job requirements right leveraging recruiters employees work wonders expand network connections absolutely current hiring process values referrals extremely highly', 'overall good advice line looks exactly like job description won obvious stuffed keywords wouldn overqualified gets fed robot parses thousands similar looking  ...

# %%
# Model topics

from bertopic import BERTopic
topic_model = BERTopic().fit(sentences, sentence_embeddings)
topic_model.get_document_info(sentences)
# Out:
#                                               Document  Topic  \
# 0    actually jobs month lol know people applying h...      1
# 1    yeahh shining shimmering splendid networking m...      0
# 2                              thank friend appreciate      0
# 3    congratulations know hard best interview thank...      0
# 4    absolutely factor issue going college coop pla...      0
# ..                                                 ...    ...
# 495  appreciate criticism post obviously agree fail...      0
# 496  create resume https play google com store apps...      0
# 497  quizzes earn dollars easily earn dollars minut...      1
# 498                                             worked      0
# 499  list experience certifications acronyms matchi...      0
#
#                                     Name  \
# 0    1_amp_earn_lifestyle_designarticles
# 1                   0_job_work_like_time
# 2                   0_job_work_like_time
# 3                   0_job_work_like_time
# 4                   0_job_work_like_time
# ..                                   ...
# 495                 0_job_work_like_time
# 496                 0_job_work_like_time
# 497  1_amp_earn_lifestyle_designarticles
# 498                 0_job_work_like_time
# 499                 0_job_work_like_time
#
#                                            Top_n_words  Probability  \
# 0    amp - earn - lifestyle - designarticles - post...     0.913622
# 1    job - work - like - time - jobs - know - good ...     1.000000
# 2    job - work - like - time - jobs - know - good ...     1.000000
# 3    job - work - like - time - jobs - know - good ...     1.000000
# 4    job - work - like - time - jobs - know - good ...     1.000000
# ..                                                 ...          ...
# 495  job - work - like - time - jobs - know - good ...     0.970469
# 496  job - work - like - time - jobs - know - good ...     1.000000
# 497  amp - earn - lifestyle - designarticles - post...     0.424676
# 498  job - work - like - time - jobs - know - good ...     1.000000
# 499  job - work - like - time - jobs - know - good ...     1.000000
#
#      Representative_document
# 0                      False
# 1                      False
# 2                      False
# 3                      False
# 4                      False
# ..                       ...
# 495                    False
# 496                    False
# 497                    False
# 498                    False
# 499                    False
#
# [500 rows x 6 columns]
