# %% [markdown]
# # Regression with Keras

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
raw_df = pd.read_csv('https://raw.githubusercontent.com/lmanikon/lmanikon.github.io/master/teaching/datasets/bostonHousing.csv')
non_null_df = raw_df.dropna()
X = StandardScaler().fit_transform(non_null_df.drop(columns="MEDV"))
y = non_null_df['MEDV']
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 25, test_size=0.2)
y
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 506    12.0
# 507    32.0
# 508    54.0
# 509    67.0
# 510    24.0
# Name: MEDV, Length: 506, dtype: float64

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras import metrics

model = Sequential()
model.add(Dense(12, input_dim=13, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='mean_squared_error', optimizer='adam', metrics=[metrics.MeanSquaredError()])
model.fit(X_train, y_train, epochs=150, batch_size=10)
# Out:
# Epoch 1/150
# 41/41 [==============================] - 1s 1ms/step - loss: 573.5952 - mean_squared_error: 573.5952
# Epoch 2/150
# 41/41 [==============================] - 0s 1ms/step - loss: 564.7181 - mean_squared_error: 564.7181
# Epoch 3/150
# 41/41 [==============================] - 0s 963us/step - loss: 559.0050 - mean_squared_error: 559.0050
# Epoch 4/150
# 41/41 [==============================] - 0s 834us/step - loss: 555.7488 - mean_squared_error: 555.7488
# Epoch 5/150
# 41/41 [==============================] - 0s 759us/step - loss: 554.2310 - mean_squared_error: 554.2310
# Epoch 6/150
# 41/41 [==============================] - 0s 845us/step - loss: 553.6227 - mean_squared_error: 553.6227
# Epoch 7/150
# 41/41 [==============================] - 0s 816us/step - loss: 553.3328 - mean_squared_error: 553.3328
# Epoch 8/150
# 41/41 [==============================] - 0s 789us/step - loss: 553.1747 - mean_squared_error: 553.1747
# Epoch 9/150
# ...

# %%
_, mse = model.evaluate(X_test, y_test)
print("Keras MSE: "+str(mse))
# Out:
# 4/4 [==============================] - 0s 1ms/step - loss: 597.8004 - mean_squared_error: 597.8004
# Keras MSE: 597.8004150390625
